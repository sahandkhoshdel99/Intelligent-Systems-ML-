# %% [markdown]
# <br><br>
#
# <font color=#0C2C76 ><font>
# <p style = "font-family:courier;">
#     <font size="7">
#         Intelligent Systems
#     </font>
# </p>
#
#  <br>
#
# <font color=#CF3A69><font>
# <p style = "font-family:optima;">
#     <font size="6">
#         Homework #3 - Neural Networks
#     </font>
# <font color=#000000> <font>
# </p>
#
# > $\textit{Sahand Khoshdel - 810196607}$

# %% [markdown]
# <font color=#0C2C76 ><font>
# <p style = "font-family:georgia;">
#     <font size="6">
#         Q1.  Theoretical Questions <br><br><br><br><b><font size="5"> <font color="#A3678F" > - A) Normalizing & Standardizing Data  </b><font></font>
#     </font>
# </p>
# <br><br>
# <font color= #094CAF><font>
# <p style = "font-family:cambria;">
#     <font size="5">
#         <b> Getting to know the family - Rescaling Operations:</b>
#     <font>
# </p>
# <font color= #00000><font>
#
# <p style = "font-family:cambria;">
#     <font size="3">
#         <b></b><b> Normalizing & Standardizing</b> Data are openrations which belong to a <b> general family </b>of data operations called <b> 'Resacling'.</b> Rescaling is by definition <b> adding,subtracting,multiplying or dividing data by a constant in order to fix its variability range in a custom range</b><br><br>This can be a part of <b> Pre-processing Data </b> in order to <b> Make it more compatible for the ML model we are using</b> , or even part of a Post-Processing procedure in order to visualize data better and make it more sensible and readable.
#         <font>
#             </p>
#
# <font color= #094CAF><font>
# <p style = "font-family:cambria;">
#     <font size="5">
#         <b> Introducing Standardization: </b>
#     <font>
# </p>
#
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         <b></b><b> Standardizing a vector means subtracting the vector's element values from an absolute value and scaling(dividing) it by a specific factor</b>. Usually these two values are the mean and std of the data. Therefore if <b> each of the Random Variables ( $\mathit{x_{i}}$ ) in a Random Vector ( $\mathit{X}$ ) (Ex; Representing Samples of a Population), have a normal distribution $\mathit{N(\mu_{i}, \sigma_{i})}$ with a mean of $\mathit{\mu_{i}}$ and standard deviation of $\mathit{\sigma_{i}}$</b> :
#         By <b> Standardizing</b> with the factors of $\mathit{\mu_{i}}$ and $\mathit{\sigma_{i}}$ we can <b> map all the random variables to a "Standard Normal Distribution" </b>$\mathit{N(0 , 1)}$
#             </p>
#
# <font color= #094CAF><font>
# <p style = "font-family:cambria;">
#     <font size="4">
#         <b> Why Standardization? </b>
#     <font>
# </p>
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         <b> Standardizing </b>the features shows its importance when we have <b> different features that yield different ranges </b>in outr training set. Suppose in a Medical Training set height and weight are features . heights are betweeen 150 to 210 cm's and weights between 40 to 200 kg's. Its obvious that when computing a statistic based on these two features, <b> without standardizing them a statistic like loss will be affected completely biased to one of the features</b> above. and <b> This bias can paralyze the learning process</b>  quite strongly.After <b> Noramlizing Features</b> we can be sure that they <b> affect our training statistics</b> in a <b>fair</b> manner.
#             </p>
#
# <font color= #094CAF><font>
# <p style = "font-family:cambria;">
#     <font size="5">
#         <b> Introducing Normalization:</b>
#     <font>
# </p>
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         <b> Normalizing” a vector most means dividing it by its norm (with any definition) so that all the element values $\mathit{x_{i}}$ fit in the (0,1) interval</b>.So by normalizing <b> feature values they shrink in a (0,1) interval</b>  and even can be interpreted in a probabilistic way if needed.
#             </p>
#
#
#
# <font color= #094CAF><font>
# <p style = "font-family:cambria;">
#     <font size="4">
#         <b>Why Normalization? / Comparison With Standardization</b>
#     <font>
# </p>
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         <b> Normalization</b> tends to make <b> different fatures</b> affect the model in a <b> common scale</b>, <br><font color= #CE3515><font><b>Differences:</b><br><font color= #00000><font>
#         Unlike Standardization, <b>Normalization maps the values to a fixed boundary of (0,1)</b>, Standardization just maps the mean to 0 and the deviation to 1 but does not ensure that outliers wont pass a certain boundary<b><br><font color= #CE3515><font>Similarites:<br><font color= #00000><font> Both Standardization and Normalization</b> make the features interaction on the model <b> fair and unbiased.</b>
#             </p>
# <br><br>

# %% [markdown]
# <font color=#0C2C76 ><font>
# <p style = "font-family:georgia;">
#     <b><font size="5"> <font color="#A3678F" > - B) Dropout, A Regularization Technique  </b><font></font>
#     </font>
# </p>
# <br><br>
#
# <font color= #094CAF><font>
# <p style = "font-family:cambria;">
#     <font size="5">
#         <b> Overfitting in Neural Nets:</b>
#     <font>
# </p>
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         <b> Deep Neural Nets</b> consist of many <b> non-linear hidden layers</b>  used to <b> extract complicated features</b>.<br><br> The <b> more you make a model complicated</b> and increase the number of layers and each layers complexity, <b> The more you need training data that is general, feature-diversive and in other words represent your population distribution as best as possible!</b>
#             </p>
# <br><br>
# <font color=#0C2C76 ><font>
# <p style = "font-family:georgia;">
#     <b><font size="4"> <font color="#CE3515" > But The Problem is: <font color=#00000 ><font>
#  DATA IS LIMITED! </b><font></font>
#     </font>
# </p>
#
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         If our training data is limited; we can use <b> many regularization techniques</b> that <b> prevent </b> the model to <b> overfit </b> the data. These methods are such as:<br>- Weight Decay using L1,L2 Regularization<br>- Data Augmentation<br>- Bagging & Ensemble Methods<br>- Striping and Max-pooling Techniques in CNN's<br>- <b>Dropout</b><br>...
#             </p>
# <br>
#
#
#
# <font color= #094CAF><font>
# <p style = "font-family:cambria;">
#     <font size="5">
#         <b> Ensemble Methods</b>
#     <font>
# </p>
#
#
#
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         Drop out is <b> one of the ensemble method techniques that helps regualrization to improve by randomly turning off the activation outputs of some of the neurons in each layer</b>. Dropout <b> prevents overfitting in training data</b>  by means of preventing <b> complex co-adaptations</b>.
#             </p>
# <br>
#
# <font color=#0C2C76 ><font>
# <p style = "font-family:georgia;">
#     <b><font size="4"> <font color="#CE3515" > So now, What is <font color=#00000 ><font>
#  Complex Co-adaptation !?</b><font></font>
#     </font>
# </p>
#
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         In neural networks, <b> co-adaptation</b> refers to when <b> different hidden units in a neural networks have highly correlated behavior</b>.This situation is a <B> sign of computational waste</b> and <b>high noise sensitivity</b> for data that consists the <b> hidden feature that multiple units </b>  are <b> detecting simultaneously</b>. <br><br> Thus it can lead to <b> Over-fitting training data </b>
#
#
#
#
# <font color= #094CAF><font>
# <p style = "font-family:cambria;">
#     <font size="5">
#         <b> What is Dropout and how does it help Regularization?</b>
#     <font>
# </p>
#
#
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         <b> Dropouts goal</b> is to <b> prevent these co -adaptations among hidden units by randomly turning their activations off</b>. Dropout mask</b> is a term that refers to a structure corresponding to outr network where each neuron(activation unit) gets a value of 0 or 1 that defines whether its on or off.<b> The dropuout mask is generated according to the dropout probability.</b> The mask can be reset before each mini-batch enters the network or even after a whole epoch</b> Many researchers have mentioned that heavy dropout (High probability) can lead to even underfitting the training data<br><br>
#             </p>
# <br>

# %% [markdown]
# <font color=#0C2C76 ><font>
# <p style = "font-family:georgia;">
#     <b><font size="5"> <font color="#A3678F" > - C) Underfitting, How to increae our networks capabilities? </b><font></font>
#     </font>
# </p>
# <br><br>
#
#
# <font color= #094CAF><font>
# <p style = "font-family:cambria;">
#     <font size="5">
#         <b> Underfitting,What it is and When it happens:</b>
#     <font>
# </p>
#
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         <b> Underfitting</b> simply means we <b> havent used are training data capabilities and features enough to generate an accurate model </b> . Underfitting is the opposite of <b> overfitting</b>  (which happens when we have made <b> our model too sensitive to training data that an outlier </b>(noisy sample) can harldy <b> decrease </b> our <b> model's entire generalization power to other data</b> (validation and testing) coming from the same distribtion.) <br><br>
#             </p>
# <br>
#
# <font color= #094CAF><font>
# <p style = "font-family:cambria;">
#     <font size="5">
#         <b>How to detect overfit/underfit using train & validation loss or accuracy?</b>
#     <font>
# </p>
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         According to the figure below, <b> overfitting</b>  happens when we have used too much features of the training set that the model doesn't generalize to the test/validation set <b> (high training acc. & Pretty low  validation acc. (big gap : (Low bias, High Variance) </b>. Likewise <b> Underfitting</b> happens when we havent used our training data's capabilities(feauteres) enough to increase the complexity and thus the accuracy of the model So <b> we should see low testing and validation accuracy with a small gap among them (cause the model is a stranger model to the features of the data driven by the distribution.</b>
#             </p>
# <br>
#
# ![Overfitting-and-underfitting-effect-on-error.png](attachment:Overfitting-and-underfitting-effect-on-error.png)
#
#
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         The figure shows the <b> relation between training and validation loss (the accuracy behaves vice versa) and the model complexity (underfit-overfit cirteria).</b> The middle range shows somehow an optimal complexity for a model we are desigining. It <b> indicates an equilibrium between Training Data Usage and Generalization Power of the model</b>
#             </p>
# <br><br><br>

# %% [markdown]
# <font color=#0C2C76 ><font>
# <p style = "font-family:georgia;">
#     <b><font size="5"> <font color="#A3678F" > - D) Learning Method: Gradient Descent via back-propagation</b><font></font>
#     </font>
# </p>
# <br><br>
# <font color= #094CAF><font>
# <p style = "font-family:cambria;">
#     <font size="5">
#         <b>Reminding Gradient Descent:</b>
#     <font>
# </p>
#
# <font color= #00000><font>
# $${\boxed{\displaystyle \mathbf {X} _{k+1}=\mathbf {X} _{k}-\alpha^{k}\; \nabla f(\mathbf {X} _{k})}}$$
#
# <br>
# <p style = "font-family:cambria;">
#     <font size="3">
#         Our <b> Objective </b> is to <b> optimize the weights </b> in a <b> neural network </b> to <b> achieve the best prediction possible</b>  for our <b> regression problem </b>This can be done using <b> Back-Propagation </b>Back-Propagation lies on a mathematical property for differentiable functions called the <b> Chain Rule: </b> </b>
#             </p>
# <br><br>$${\displaystyle \boxed{{\frac {dC}{da^{L}}}\cdot {\frac {da^{L}}{dz^{L}}}\cdot {\frac {dz^{L}}{da^{L-1}}}\cdot {\frac {da^{L-1}}{dz^{L-1}}}\cdot {\frac {dz^{L-1}}{da^{L-2}}}\cdots {\frac {da^{1}}{dz^{1}}}\cdot {\frac {\partial z^{1}}{\partial x}}.}}$$<br>In the <b> Chain Rule </b> The derivatives (gradients) with respect to any weight in the network can be derived from the derivatives(gradients) with respect to next layer weights. The <b> Loss Function </b> is usually considered to be an <b> MSE </b> in regression problems.

# %% [markdown]
# ![NN1.jpeg](attachment:NN1.jpeg)

# %% [markdown]
# ![NN2.jpeg](attachment:NN2.jpeg)

# %% [markdown]
# ![NN3.jpeg](attachment:NN3.jpeg)

# %% [markdown]
# ![NN4.jpeg](attachment:NN4.jpeg)

# %% [markdown]
# <font color=#0C2C76 ><font>
# <p style = "font-family:georgia;">
#     <font size="6">
#         Q2. Neural Network from scratch <br><br><font size="5">
#     </font>
# </p>
#
# <font color=#0C2C76 ><font>
# <p style = "font-family:georgia;">
#     <b><font size="5"> <font color="#A3678F" >  Basic Elements of a Neural Network </b><font></font>
#     </font>
# </p>
# <br><br>
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         <b> 1.Neural Network Units:</b> <br>
#         1.1: Neurons <br>1.2: Weights<br>1.3: Biases<br> 1.4: Activation Functions<br>1.5: Loss Function<br><br>
#         <b> 2.Neual Network main functions:<br></b>
#         2.1: Feed Forward<br>2.2: Loss Calculation<br>2.3: Back-propagation and weigh updating<br><br>
#         <b> 3.Auxilery Functions(Operators):</b><br>
#         3.1: Dot Product(np.dot)<br>3.2: Gradient(From HW_1) <br>
#        </font>
# </p>

# %% [markdown]
# <p style = "font-family:georgia;">
#     <b><font size="5"> <font color="#D6274F" >  - Neural Network Units </b><font></font>
#     </font>
# </p>
#
# <p style = "font-family:georgia;">
#     <b><font size="4"> <font color="#A3678F" >  1.1: Neurons </b><font></font>
#     </font>
# </p>

# %%
import numpy as np
def neuron(inputs,weights,bias):
    return (np.dot(inputs,weights)+bias)

# %% [markdown]
# <p style = "font-family:georgia;">
#     <b><font size="4"> <font color="#A3678F" >  1.2: Weights </b><font></font>
#     </font>
# </p>
#
# <p style = "font-family:georgia;">
#     <b><font size="3"> <font color="#6D81B9" >  How to initialize weights of a neural network? </b><font></font>
#     </font>
#         </p>
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         One solution is to use <b> "Xavier Initialization"</b>.This Weight initialization is based on the goal of making the <b> variance of the activations similar across every layer</b> . This constant variance helps <b> prevent the gradient from exploding or vanishing.</b><br>
# <br>The <b> random weights </b> come from a <b> uniform distribution </b> in the following range:<br><br>$${W_{ij} \sim U\left[-\frac{1}{\sqrt{n}}, \frac{1}{\sqrt{n}}\right]}$$<br> Where <b> ${U}$ is the 'Uniform Distribution'</b>  and n is the <b>  "previous layer size'</b>

# %%
def weight_initializer(prev_node_num,next_node_num):
    weights = np.zeros(prev_node_num*next_node_num)
    n = prev_node_num
    weights = np.random.uniform(-1/np.sqrt(n), 1/np.sqrt(n), size = prev_node_num*next_node_num)
    weights = weights.reshape(next_node_num,prev_node_num)
    return weights

weight_initializer(3,4)
# Out:
# array([[-0.04384372,  0.18934073,  0.43487409],
#        [ 0.45420223, -0.45902198, -0.4975922 ],
#        [ 0.22814252, -0.15972912,  0.3344342 ],
#        [ 0.02970209,  0.18197737, -0.27040197]])

# %% [markdown]
# <p style = "font-family:georgia;">
#     <b><font size="4"> <font color="#A3678F" >  1.3: Biases </b><font></font>
#     </font>
# </p>
# <br>
# <p style = "font-family:georgia;">
#     <b><font size="3"> <font color="#6D81B9" >  How to initialize biases of a neural network? </b><font></font>
#     </font>
#         </p>
#
# <p style = "font-family:cambria;">
#     <font size="3">
#        Its very simple. It's common to initialize bias to 0, since the asymmetry breaking is provided by the small random numbers in the weights.<br> But for <b> ReLU non-linearities, It's recommmended to to use small constant value such as 0.01</b>  for all biases because this <b> ensures that all ReLU units fire in the beginning and therefore obtain and propagate some gradient.</b>

# %% [markdown]
# <p style = "font-family:georgia;">
#         <b><font size="4"> <font color="#A3678F" >  1.4: Activations </b><font></font>
#     </font>
# </p>
# <br>

# %%
def tanh(x):
    return np.tanh(x)

def relu(x):
    out = np.zeros(len(x))
    for i in range(len(x)):
        out[i] = max(0,x[i])
    return out

# %% [markdown]
# <br><br><p style = "font-family:georgia;">
#     <b><font size="5"> <font color="#D6274F" >  - Neural Network Main Functions </b><font></font>
#     </font>
# </p>
#
# <p style = "font-family:georgia;">
#     <b><font size="4"> <font color="#A3678F" >  2.2: Feed-Forward: </b><font></font>
#     </font>
# </p>
# <br>

# %%
def neural_net(inputs,hidden_layer_sizes,output_size,hl_activation = 'tanh'):
    
    # list to numpy array conversion in case of entering a list:
    inputs = np.array(inputs)
    hidden_layer_sizes = np.array(hidden_layer_sizes)
    output_size = np.array(output_size)
    
    # attaching input and output size to hidden_layer sizes:
    layer_nums = len(hidden_layer_sizes) + 2 
    layer_sizes = np.insert(hidden_layer_sizes, 0,len(inputs))
    layer_sizes = np.append(layer_sizes,output_size)
    
    weights = []
    weights = np.array(weights)
    biases = np.zeros(layer_nums-1)
    
    z = np.zeros(layer_nums-1)
    a = np.zeros(layer_nums-1)
    
    # weights and bias initialization/designing the path from input to output, layer by layer; 
    prev_val = inputs 
    
    for i in range(1,layer_nums):
        prev_size = layer_sizes[i-1]
        next_size = layer_sizes[i]

        layer_weights = weight_initializer(prev_size,next_size)
        
        if(hl_activation == "relu"):
            bias = 0.1
            biases = np.append(biases,bias)
        

        #print(f"layer weights {i},{i+1}:\n\n {layer_weights}\n\n\n\n")
        weights = np.append(weights,layer_weights)  
        
    
    
    
    return weights,biases,activations

#neural_net([1,2,3],[4,5],2)

def feed_forward(neural_net):
    z[i] = np.matmul(np.transpose(layer_weights),prev_val + biases[i-1])
    a[i] = activation(z[i])
    prev_val = a[i]
    pass

# %% [markdown]
# <font color=#0C2C76 ><font>
# <p style = "font-family:georgia;">
#     <font size="6">
#         Q3. Neural Network Development using Keras API <br><br><font size="5">
#     </font>
# </p>
#
# <font color= #00000><font>
# <p style = "font-family:cambria;">
#     <font size="3">
#         We are going to use the <b> fashion MNIST </b> Data set for developing our model.<b> Let's have a closer look </b> to this dataset and its properties.
#             </p>

# %% [markdown]
# ![fashio%20MNIST.jpeg](attachment:fashio%20MNIST.jpeg)

# %% [markdown]
# <p style = "font-family:cambria;">
#     <font size="3">
#         This dataset consists of <b> 70,000 28*28 images</b>  that are split into <b> 60,000 training images</b>  and <b> 10,000 test images</b>. The <b> 10 different class labels</b> are:<br><br>
# 0 - T-shirt/top<br>
# 1 - Trouser<br>
# 2 - Pullover<br>
# 3 - Dress<br>
# 4 - Coat<br>
# 5 - Sandal<br>
# 6 - Shirt<br>
# 7 - Sneaker<br>
# 8 - Bag<br>
# 9 - Ankle boot<br><br><br>
#         The Network should learn to <b> classify these images into their corresponding groups</b> . As we are dealing with a multi-class classification problem we can use <b> one-hot encoding </b> in the <b> output layer </b> for <b> label representation</b>
#             </p>

# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.utils import np_utils



train_set = pd.read_csv (r'fashion-mnist_train.csv').to_numpy()   #read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't forget to put the file name at the end of the path + ".csv"
train_labels = train_set[:,0]
train_samples  = train_set[:,1::]

test_set = pd.read_csv(r'fashion-mnist_test.csv').to_numpy()
test_labels = test_set[:,0]
test_samples  = test_set[:,1::]

num_label = len(np.unique(train_labels))

hidden_layer_num = 2

# %%
def noramlize_image(data):
    return data/255.0

def model_constructer(d,neuron_count,label_num,num_epoch,act_function='relu',dropout=False,dropout_rate=0.1,batch_norm=False,optimizer ='adam',metric='acc') :
    if (dropout==True):
        model = Sequential([
            tf.keras.layers.Flatten(input_shape=(d, d)),
            tf.keras.layers.Dense(neuron_count[0], activation=act_function),
            tf.keras.layers.Dropout(dropout_rate), 
            tf.keras.layers.Dense(neuron_count[1], activation=act_function),
            tf.keras.layers.Dense(label_num),
        ])   
    else:
        model = Sequential([
            tf.keras.layers.Flatten(input_shape=(d, d)),
            tf.keras.layers.Dense(neuron_count[0], activation=act_function),
            tf.keras.layers.Dense(neuron_count[1], activation=act_function),
            tf.keras.layers.Dense(label_num),
        ])
        
    model.compile(optimizer, loss = 'sparse_categorical_crossentropy',metrics = [metric])
    history = model.fit(train_samples, train_labels, epochs = num_epoch, validation_data = (test_samples, test_labels))
    return model,history
    
num_epoch = 20    
neuron_count = [0]*hidden_layer_num
neuron_count = [128,50]
image_dimensions = 28

print(neuron_count)
md = model_constructer(image_dimensions, neuron_count,num_label,num_epoch)
md.evaluate(test_samples, test_labels, verbose = 2)
# Out:
# [128, 50]
# Epoch 1/20
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input Tensor("flatten_5_input:0", shape=(None, 28, 28), dtype=float32), but it was called on an input with incompatible shape (32, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input Tensor("flatten_5_input:0", shape=(None, 28, 28), dtype=float32), but it was called on an input with incompatible shape (32, 784).
# ...
# 1875/1875 [==============================] - 2s 1ms/step - loss: 8.0802 - acc: 0.1444 - val_loss: 2.3026 - val_acc: 0.1026
# Epoch 2/20
# 1875/1875 [==============================] - 2s 912us/step - loss: 2.3025 - acc: 0.1019 - val_loss: 2.3026 - val_acc: 0.1026
# Epoch 3/20
# 1875/1875 [==============================] - 2s 948us/step - loss: 2.3025 - acc: 0.1019 - val_loss: 2.3026 - val_acc: 0.1026
# Epoch 4/20
# 1875/1875 [==============================] - 2s 919us/step - loss: 2.3025 - acc: 0.1019 - val_loss: 2.3026 - val_acc: 0.1026
# ...

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.utils import to_categorical
import tensorflow as tf

HIDDEN_NEURONS1 = 128
HIDDEN_NEURONS2 = 50
DROPOUT = 0.1
EPOCHS = 20
LABEL_COUNT = 10
SHAPE = 28
# Out:
# ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/utils/data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     277       try:
# --> 278         urlretrieve(origin, fpath, dl_progress)
#     279       except HTTPError as e:
#
# /usr/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#
# /usr/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /usr/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
# ...
